# %%
# %%bash
# cat << EOF > hello.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     cout << "Hello C++ from Google Colab";
#     return 0;
# }
# EOF
#
# g++ hello.cpp -o hello
# ./hello
# Out:
# Hello C++ from Google Colab

# %%
# %%bash
# cat << EOF > hello.cpp
# #include <iostream>
# using namespace std;
# int add(int a, int b){
#     return a+b;
# }
# int main() {
#     int result = add(1,2);
#     cout<<"Function Result = "<<result;
#     return 0;
# }
# EOF
#
# g++ hello.cpp -o hello
# ./hello
# Out:
# Function Result = 3
